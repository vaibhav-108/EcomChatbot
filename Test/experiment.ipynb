# %%
print("hello")
# Out:
# hello

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
from groq import Groq

client = Groq(api_key= os.environ.get("GROQ_API_KEY"))


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of low latency LLMs",
        }
    ],
    model="openai/gpt-oss-20b",
)
print(chat_completion.choices[0].message.content)
# Out:
# ## Why Low‑Latency LLMs Matter
#
# Large Language Models (LLMs) have become ubiquitous—from virtual assistants to content creation, from real‑time translation to autonomous systems. In most of these scenarios, **the time it takes a model to generate a response (latency) is a critical quality‑of‑service (QoS) metric**. Below we break down the reasons why low latency is not just a nicety but a hard requirement in many contexts, what “low latency” actually means, and how it shapes the design of the entire LLM stack.
#
# | Context | Typical Latency Target | Why It Matters |
# |---------|-----------------------|----------------|
# | **Chatbots & Conversational AI** | 200 ms – 1 s per turn (real‑time) | Users expect a human‑like “conversation flow.” A 1‑second wait feels like a pause in the conversation. |
# | **Voice Assistants** | < 300 ms (wake‑word + first response) | Voice interfaces are sensitive to any lag; a lag can break the “hands‑free” experience. |
# | **Real‑time Translation** | < 300 ms per sentence | Allows live subtitles or instant interpretation during a call or live event. |
# | **Gaming & Interactive Storytelling** | < 50 ms per frame | Any delay can ruin immersion or make controls feel sluggish. |
# | **Autonomous Systems (self‑driving, robotics)** | < 10 ms for safety-critical decisions | Delayed perception‑to‑action loops can lead to collisions or unsafe behavior. |
# | **Financial Trading Bots** | < 1 ms | Milliseconds can translate to millions of dollars in trading advantage. |
# | **Edge / IoT devices** | 10–200 ms (often with power constraints) | Real‑time processing is required for sensor fusion, local privacy, and low bandwidth. |
#
# ### 1. User Experience (UX) & Retention
#
# - **Perceived Speed vs. Real Speed**
#   Even if the network round‑trip is minimal, model inference can dominate latency. Users are sensitive to delays; a 1 s delay can feel like a “hang” or even cause them to abandon a chat prematurely.
#
# - **Cognitive Load**
#   Longer waits require users to keep their thought processes active, increasing cognitive load and potentially leading to errors or frustration.
#
# - **Churn & Revenue**
#   In commercial services, higher latency correlates with higher churn rates. A study of 10 SaaS platforms found that every 100 ms increase in average page‑load time reduced conversion by 1–2 %.
#
# ### 2. Real‑time Decision Making
#
# - **Safety**
#   Autonomous vehicles, medical devices, and industrial control systems need decisions in milliseconds; any lag can be catastrophic.
#
# - **Synchronous Collaboration**
#   In VR/AR or real‑time editing tools, latency can create a “lag” effect where participants see each other’s actions delayed, breaking immersion.
#
# ### 3. Cost & Efficiency
#
# - **Compute Utilization**
#   High‑latency inference often means the compute engine is idle for longer periods while waiting for responses, leading to lower utilization and higher cost per inference.
#
# - **Throughput vs Latency Trade‑off**
#   Batch inference can dramatically improve throughput (GPU utilization), but it introduces latency. For latency‑sensitive workloads, you pay for “latency budget” with more powerful hardware or specialized accelerators.
#
# - **Energy Consumption**
#   Latency also correlates with energy per token. A model that takes 1 s to generate a response might consume as much power as a batch of 10 responses, so optimizing for latency can also be energy‑efficient in many use‑cases.
#
# ### 4. Competitive Advantage
#
# - **Feature Differentiation**
#   Companies that can offer instantaneous responses (e.g., “Ask anything, get answer in 200 ms”) can differentiate in crowded markets.
#
# - **Ecosystem Integration**
#   Low‑latency LLMs can be used as the “brain” for other systems (e.g., smart home assistants) that expect rapid, on‑device inference.
#
# ---
#
# ## Defining “Low Latency”
#
# - **End‑to‑End**: From the moment the user submits a prompt to when the first token appears on the screen.
# - **Token‑wise**: The average time between tokens during generation, important for streaming use‑cases.
# - **In the Cloud vs Edge**: Cloud latency includes network hops; edge latency is purely compute time.
#
# Typical benchmarks:
# | Use‑Case | Latency Target | Notes |
# |----------|----------------|-------|
# | Conversational (chat) | ≤ 300 ms | Acceptable “human‑like” pacing |
# | Voice (speech‑to‑text + LLM) | ≤ 200 ms | Enables “talk‑to‑assistant” |
# | Real‑time translation | ≤ 300 ms | Keeps subtitles “in sync” |
# | Edge inference | ≤ 50 ms | Often with power budgets |
#
# ---
#
# ## Key Drivers of LLM Latency
#
# | Layer | Typical Bottleneck | Mitigation Strategies |
# |-------|--------------------|-----------------------|
# | **Model Size & Architecture** | Large token‑embedding matrices, deep attention layers | Distillation, quantization, sparsity, dynamic routing |
# | **Sequence Length** | Longer prompts → more compute | Prompt truncation, chunking, efficient context windows |
# | **Hardware** | CPU vs GPU vs ASIC | GPUs with tensor cores, TPUs, FPGAs, NPU accelerators |
# | **Software Stack** | Framework overhead, inter‑process communication | Optimized kernels (cuBLAS, MKL‑DNN), ONNX Runtime, Triton |
# | **Batching** | Large batches increase latency | Use “micro‑batching” or “asynchronous pipeline” for streaming |
# | **Data Movement** | PCIe / NVLink transfers, memory copies | Zero‑copy buffers, pinned memory, RDMA |
# | **Network** | RTT, packet loss | Edge deployment, CDN caching, local inference |
#
# ---
#
# ## Techniques for Low‑Latency Inference
#
# 1. **Model Distillation & Size Reduction**
#    - *Teacher–Student Distillation*: Train a smaller student model to mimic a large teacher.
#    - *Parameter‑Efficient Fine‑Tuning (PEFT)*: LoRA, Adapter layers keep most parameters frozen, enabling lighter inference.
#
# 2. **Quantization**
#    - *INT8/FP16*: 8‑bit integer or 16‑bit floating point reduces memory bandwidth and computational cost.
#    - *Post‑Training Quantization (PTQ)* and *Quantization‑Aware Training (QAT)* maintain accuracy.
#
# 3. **Pruning & Sparsity**
#    - Structured pruning (removing entire attention heads, layers) or unstructured sparsity with sparse kernels can cut FLOPs.
#    - Hardware like NVIDIA Ampere’s sparsity or Intel’s Scalable ML (SML) support sparse operations.
#
# 4. **Caching & Token Reuse**
#    - *Key‑Value Cache*: Reuse past hidden states for autoregressive generation to avoid recomputing attention over the whole context.
#    - *Beam Search Caching*: Store intermediate states for each hypothesis in beam search.
#
# 5. **Prompt Engineering**
#    - Shorten prompts, use concise instructions, or provide embeddings once and reuse them.
#    - Chunk long documents into overlapping windows and process them in parallel.
#
# 6. **Optimized Inference Engines**
#    - **TensorRT**, **OpenVINO**, **ONNX Runtime**, **Triton**: Compile models to the most efficient kernels for target hardware.
#    - *Dynamic Tensor Parallelism*: Split layers across GPUs to balance latency vs throughput.
#
# 7. **Edge/On‑Device Deployment**
#    - Deploy quantized, distilled models to mobile NNEs (e.g., Apple ML Compute, Qualcomm Snapdragon NPU) or embedded ASICs.
#    - Use model partitioning: Keep the core LLM on the cloud, but run lightweight “edge wrappers” for pre‑processing or post‑processing.
#
# 8. **Streaming Generation**
#    - Generate tokens incrementally (as soon as the first token is ready). This gives the illusion of instant response.
#    - Use *prefill‑compute* pipelines: Compute attention for the whole prompt once, then stream decoding.
#
# ---
#
# ## Real‑World Examples & Case Studies
#
# | Company | Approach | Result |
# |---------|----------|--------|
# | **OpenAI** (ChatGPT) | 4‑bit quantization + model pruning + specialized GPU pipelines | 2–3× speed‑up on NVIDIA A100s, ~40 ms per token on a single

# %%
from pymongo import MongoClient
mongo_url = os.getenv("MONGO_URI")

client = MongoClient(mongo_url)
db = client["Ecommerce"]

collection = db["products"]

# %%
product = {
    'name': 'men casual shirt',
    'price':999,
    'category': 'men',
    'size': ['S', 'M', 'L', 'XL'],
    'color': ['White', 'Blue']
}

result=collection.insert_one(product)
result.inserted_id
# Out:
# ObjectId('69d7d4af4adca92d57681fab')

# %%
products = [
    {
        'name': 'men casual shirt',
        'price': 999,
        'category': 'men',
        'size': ['S', 'M', 'L', 'XL'],
        'color': ['White', 'Blue'],
    },
    {
        'name': 'men formal shirt',
        'price': 1499,
        'category': 'men',
        'size': ['M', 'L', 'XL'],
        'color': ['White', 'Black'],
    },
]

result=collection.insert_many(products)
result
# Out:
# InsertManyResult([ObjectId('69d881ed4adca92d57681fac'), ObjectId('69d881ed4adca92d57681fad')], acknowledged=True)

# %%
all_products = collection.find()
for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('69d7d4574adca92d57681fa9'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d7d4734adca92d57681faa'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d7d4af4adca92d57681fab'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d881ed4adca92d57681fac'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d881ed4adca92d57681fad'), 'name': 'men formal shirt', 'price': 1499, 'category': 'men', 'size': ['M', 'L', 'XL'], 'color': ['White', 'Black']}

# %% [markdown]
# Find

# %%
men_produc=collection.find({'category': 'men'})

for p in men_produc:
    print(p)
# Out:
# {'_id': ObjectId('69d7d4574adca92d57681fa9'), 'name': 'men casual shirt', 'price': 799, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d7d4734adca92d57681faa'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d7d4af4adca92d57681fab'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d881ed4adca92d57681fac'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d881ed4adca92d57681fad'), 'name': 'men formal shirt', 'price': 1499, 'category': 'men', 'size': ['M', 'L', 'XL'], 'color': ['White', 'Black']}

# %% [markdown]
# Update

# %%
collection.update_one({'name': 'men casual shirt'}, {'$set': {'price': 799}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000106'), 'opTime': {'ts': Timestamp(1775797614, 1095), 't': 262}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1775797614, 1095), 'signature': {'hash': b'\x1ae\x03pa\xc3\x91i\x8b\x88\xf2|Y\xab\xba\x04\x14\xbd\xb5Y', 'keyId': 7584871876338384898}}, 'operationTime': Timestamp(1775797614, 1095), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Delete

# %%
collection.delete_one({'name': 'men formal shirt'})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000106'), 'opTime': {'ts': Timestamp(1775797784, 10), 't': 262}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1775797784, 10), 'signature': {'hash': b'u\xda\x82\xecC\x8f\xfb-\xce\xa2\xb5\x88\x9at> \xb3\xf3}\xe8', 'keyId': 7584871876338384898}}, 'operationTime': Timestamp(1775797784, 10)}, acknowledged=True)

# %%
men_produc=collection.find({'category': 'men'})

for p in men_produc:
    print(p)
# Out:
# {'_id': ObjectId('69d7d4574adca92d57681fa9'), 'name': 'men casual shirt', 'price': 799, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d7d4734adca92d57681faa'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d7d4af4adca92d57681fab'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}
# {'_id': ObjectId('69d881ed4adca92d57681fac'), 'name': 'men casual shirt', 'price': 999, 'category': 'men', 'size': ['S', 'M', 'L', 'XL'], 'color': ['White', 'Blue']}

# %%
collection.delete_many({})
# Out:
# DeleteResult({'n': 4, 'electionId': ObjectId('7fffffff0000000000000106'), 'opTime': {'ts': Timestamp(1775800623, 233), 't': 262}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1775800623, 256), 'signature': {'hash': b'T-\xa2]\xe1\xc6f\xceQ\xdaIQx\xf9?5\xb2\xa9J\x99', 'keyId': 7584871876338384898}}, 'operationTime': Timestamp(1775800623, 233)}, acknowledged=True)

# %%
men_produc=collection.find({'category': 'men'})

for p in men_produc:
    print(p)
